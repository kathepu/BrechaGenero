# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style-"whitegrid")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
# ----> 4 sns.set_theme(style-"whitegrid")
#
# NameError: name 'style' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")

# %%
df = pd.read_csv("../data/casen_sintetico.csv")
df.head()
# Out:
#    genero  edad              region nivel_educacion sector_economico  \
# 0  Hombre    15       Metropolitana          Básica              NaN
# 1   Mujer    60          Valparaíso         Técnica              NaN
# 2  Hombre    60  Arica y Parinacota          Básica        Industria
# 3  Hombre    34            Coquimbo   Universitaria         Comercio
# 4   Mujer    50               Ñuble   Universitaria              NaN
#
#   situacion_laboral  ingreso_mensual
# 0          Inactivo              NaN
# 1          Inactivo              NaN
# 2           Ocupado         466000.0
# 3           Ocupado         611000.0
# 4          Inactivo              NaN

# %%
print(f"Filas: {df.shape[0]:,} | Columnas: {df.shape[1]}")
# Out:
# Filas: 10,000 | Columnas: 7

# %%
df.dtypes
# Out:
# genero                object
# edad                   int64
# region                object
# nivel_educacion       object
# sector_economico      object
# situacion_laboral     object
# ingreso_mensual      float64
# dtype: object

# %%
df.isna().sum()
# Out:
# genero                  0
# edad                    0
# region                  0
# nivel_educacion         0
# sector_economico     3974
# situacion_laboral       0
# ingreso_mensual      3974
# dtype: int64

# %%
df["genero"].value_counts()
# Out:
# genero
# Mujer     5134
# Hombre    4866
# Name: count, dtype: int64

# %%
df["edad"].hist(bins=25)
plt.title("Distribucion de edad")
plt.xlabel("Edad (Anos)")
plt.ylabel("Numero de personas")
plt.show()

# %%
df["Genero"].value_counts().plot(kind="bar", color=["#dd8452", "#4c72b0"])
plt.title("Composicion por genero")
plt.ylabel("N personas")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/katy/.venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Genero'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ...

# %%
df["genero"].value_counts().plot(kind="bar", color=["#dd8452", "#4c72b0"])
plt.title("Composicion por genero")
plt.ylabel("N personas")
plt.show()
